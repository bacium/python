# %%
print("jupyter测试数据")
# Out:
# jupyter测试数据

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %% [markdown]
# #测试数据
# -子主题
#     -测试自主题
# **这是加粗语法**
# ==这个忘了是什么语法了==

# %%
"""
    1、快捷键整理
        y:切换命令
        m:markdown格式
        a:前面插入一行
        b:后面插入一行
    2、编辑模式
        enter:编辑模式写入字符
        ctrl+enter:运行当前命令，光标停止在当前行
        shift+enter:执行当前命令，光标切换到下一行
        ctrl+/:注释和取消注释
"""
