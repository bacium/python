# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
# 获取数据
data=pd.read_csv('./data/car_sale.csv')
label=data.iloc[:,1]
x_train,x_test,y_train,y_test= train_test_split(data,label,test_size=0.3,random_state=22)
print(f"训练集特征:{x_train}") 
print(f"测试集特征{x_test}")
print(f"训练集标签:{y_train}")
print(f"测试集标签:{y_test}")
# Out:
# 训练集特征:   电视广告数(x)  汽车销售数(y)
# 3         1        17
# 0         1        14
# 4         3        27
# 测试集特征   电视广告数(x)  汽车销售数(y)
# 1         3        24
# 2         2        18
# 训练集标签:3    17
# 0    14
# 4    27
# Name: 汽车销售数(y), dtype: int64
# 测试集标签:1    24
# 2    18
# Name: 汽车销售数(y), dtype: int64

# %%
#标准化数据
transfer=StandardScaler()
x_train=transfer.fit_transform(x_train)
x_test=transfer.transform(x_test)

# %%
# 模型训练
model=LinearRegression()
model.fit(x_train,y_train)

print(f"斜率:{model.coef_}")
print(f"截距:{model.intercept_}")
# Out:
# 斜率:[2.56395025e-15 5.55777733e+00]
# 截距:19.333333333333332
