# %%
import matplotlib.pyplot as plt
import os
import random
# 解决中文乱码问题.  思路1: 本机(或者虚拟机)安装SimHei字体.    思路2: 导包, 配置字体.
# 设置显示中文字体
plt.rcParams['font.sans-serif'] = ['SimHei']
# 设置正常显示符号
plt.rcParams['axes.unicode_minus'] = False
print(os.getcwd())
os.chdir("E:\python\project\python\matplotlib")
# Out:
# E:\python\project\python\matplotlib

# %%
# 创建数据
x=[i for i in range(60)]
y_bj=[random.uniform(5,18) for i in range(60)]
print(y_bj)
y_js=[random.uniform(16,23) for i in range(60)]
print(y_js)
# Out:
# [9.46624306566125, 17.939648206327746, 10.960629510438483, 14.933125080010639, 5.629102911893701, 12.343504727193391, 6.920304120988357, 14.227095912556026, 9.4661245880385, 5.994271332265265, 10.099594115144122, 10.913278280337469, 17.319073745090538, 16.743152748439922, 6.537591578216262, 9.626493667814618, 12.633227472999998, 17.83473022996231, 7.248191870768109, 5.723377188142942, 11.727929551733276, 8.992626147150549, 5.8008820274563195, 9.014147091941958, 17.467949910869557, 8.363700724277425, 8.075490032219477, 14.2183231907398, 9.9630564187451, 14.063397615918346, 12.213406301224765, 12.205712874245958, 10.7389586206147, 17.1805878583788, 10.117905383067061, 14.670563118549982, 7.217278348107271, 10.714239485612087, 12.091934879065715, 14.304809736037239, 12.777960484335587, 11.573736162547434, 11.24923391867869, 15.241594382438269, 12.60747760039876, 8.159452870188659, 17.028368992362523, 14.136966850115805, 11.932404118613427, 8.078967100268844, 10.385266862346196, 8.547898592343966, 9.483061000824872, 13.200251023910887, 5.1700484739048855, 10.86526326675596, 17.048312067026412, 5.8087707374923365, 17.53855925412261, 16.350820542256166]
# [20.654518230400317, 19.381770586057026, 22.55814213915621, 19.899349556759738, 19.599326519952537, 20.12724325628877, 22.232749012850082, 21.22581460823672, 16.36504635220977, 20.30597148594108, 18.390489564339106, 19.41477533665602, 20.089265021330593, 21.262228438727877, 20.141727128277076, 21.750539759271437, 18.917120340227612, 18.92329625778456, 20.272501793140872, 19.06926068851319, 21.65907345220223, 18.652119528184144, 18.42516869968295, 16.369197537781325, 20.778376511301943, 22.909180976572344, 22.084817460379362, 22.731890763016523, 16.015132732002254, 21.04602176617952, 19.326888948497214, 20.251609493363908, 20.544425668693563, 19.275971277067065, 18.597825086773405, 17.14536752782623, 21.73544044646312, 21.367739809502787, 16.36275920378739, 18.252365244323773, 19.161655857974054, 20.900850583690186, 17.052471057364883, 22.000529601114515, 19.755027537448882, 17.161952724309046, 16.22770216570058, 22.529958470816226, 19.759586351087066, 21.48815896805528, 19.88321015018868, 22.56882489895081, 17.448006070056653, 19.8522461892361, 18.604026288128466, 22.428960515497277, 18.207656317325057, 16.056815310827034, 22.69250835198092, 16.32769685553452]

# %%
# 创建画布
plt.figure(figsize=(30,15),dpi=80)
# 渲染图
plt.plot(x,y_bj,color="r",label="北京")
plt.plot(x,y_js,color="b",label="江苏")
# 设置 x,y 坐标轴刻度
x_ticks_label=[f"11时{i}分" for i in range(60)]
y_ticks=[i for i in range(0,30)]
plt.xticks(x[::5],x_ticks_label[::5])
plt.yticks(y_ticks[::5])
# 设置坐标轴文本信息
plt.ylabel("温度",fontsize=15)
plt.xlabel("时间",fontsize=15)

# 图标题
plt.title("北京/江苏温度统计图",fontsize=20)

# 图例
plt.legend(loc=0,fontsize=15)
# 保存图片
plt.savefig('./images/doubleTemp.jpeg')

# 展示图形
plt.show()

# %% [markdown]
# ## 面向对象方式绘图 -> 1个画板多个坐标系

# %%
# 创建数据
# 创建数据
x=range(60)
y_bj=[random.uniform(5,20) for i in x]
print(y_bj)
y_js=[random.uniform(12,26) for i in x]
print(y_js)
# Out:
# [19.007594910319874, 16.833842904317525, 16.59057547219381, 13.799417308773403, 14.054559380837837, 15.347978400402754, 13.462837035558174, 14.7083491391996, 11.063653653487819, 11.683416206594483, 17.175970436623295, 15.20972255461828, 15.327254336233342, 7.176248989382995, 12.7053630407765, 19.589916938405544, 12.692891658678711, 17.806450206885206, 15.873421979618762, 5.956973390672786, 17.58031794278487, 14.224821496457244, 16.67780866883977, 6.8896558781158665, 10.775610435524877, 12.649351211159441, 9.442283562666766, 5.108660449091941, 19.739381476957135, 15.180014988244608, 16.114311287681325, 14.614453176828363, 7.4150609105006815, 15.515816067223366, 11.214730103934784, 16.34193639175215, 18.900730521659433, 19.095241531173354, 6.399402811092996, 5.190413191811545, 9.457604005907264, 7.983818883161474, 9.66504551249948, 17.707628841086354, 5.321654265490408, 11.096487142345346, 17.90947434145081, 14.069109479688134, 8.295006584015518, 10.873376255431182, 10.913410622468884, 11.23462350215308, 17.79822490853654, 6.964941311682394, 17.11256832546507, 17.808057840480632, 19.05844460846342, 10.627526497276007, 10.883017505345876, 10.901487464123775]
# [16.780692570689027, 19.436484196073053, 24.046654434535334, 19.898461867576227, 25.311734618933745, 21.956675405504406, 22.97820535568066, 18.905993638095325, 20.992984135217668, 25.989983918313747, 13.393758618751106, 13.505747392409042, 22.36436470798657, 22.19131010924432, 18.723223426962967, 21.54388365563147, 15.735330539245155, 13.155800443723304, 20.686980590702472, 19.026378955615264, 24.024388861928486, 19.145691845297467, 17.673127380100244, 20.4222225344459, 20.070004435952825, 15.974834321618564, 23.535635969511482, 17.850571611663494, 15.418148975655669, 20.31809493725816, 17.121016471610247, 16.105272329447562, 17.408996711053266, 24.05845915944566, 21.519745529680105, 25.189731016635182, 18.480644777462985, 17.476749369045663, 23.53134358367824, 19.61513418788814, 13.724579978062119, 23.12172212379566, 17.31028808166903, 21.225483113667785, 22.600142392059084, 17.417208657269622, 12.483887328608965, 23.557440777890506, 23.79484004000549, 12.416209222453372, 22.81943972696937, 14.93256593460265, 22.17707536308229, 24.400688707764438, 12.879280772726124, 19.87095908895769, 19.43385542145763, 13.482597332607437, 14.688020359421476, 20.19603164503399]

# %%
# 创建画布

fig,ax=plt.subplots(figsize=(30,15),nrows=1,ncols=2)
y_ticks = [i for i in range(0, 30)]
# 渲染图
ax[0].plot(x,y_bj,color="r",label="北京")
ax[1].plot(x,y_js,color="b",label="江苏")

# 设置纵坐标名称
ax[0].set_ylabel("温度",fontsize=20)
ax[1].set_ylabel("温度",fontsize=20)
# 设置横坐标名称
ax[0].set_xlabel("时间",fontsize=20)
ax[1].set_xlabel("时间",fontsize=20)

# 设置横坐标刻度
ax[0].set_xticks(x[::5],[f"12时{i}分" for i in x][::5])
ax[1].set_xticks(x[::5],[f"12时{i}分" for i in x][::5])

#设置纵坐标刻度
ax[0].set_yticks(y_ticks[::5])
ax[1].set_yticks(y_ticks[::5])

# 设置图例
ax[0].legend(loc=0,fontsize=15)
ax[1].legend(loc=0,fontsize=15)

# 设置图形标题
ax[0].set_title("北京中午小时温度",fontsize=25)
ax[1].set_title("江苏中午小时温度",fontsize=25)

# 保存图表
plt.savefig('./images/beijing_jiangsu_temp.jpeg')

plt.show()
