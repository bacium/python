# %%
import matplotlib.pyplot as plt
import os
import random
# 解决中文乱码问题.  思路1: 本机(或者虚拟机)安装SimHei字体.    思路2: 导包, 配置字体.
# 设置显示中文字体
plt.rcParams['font.sans-serif'] = ['SimHei']
# 设置正常显示符号
plt.rcParams['axes.unicode_minus'] = False
print(os.getcwd())
# os.chdir("E:\python\project\python\matplotlib")
os.chdir("/Users/baidengchao/Desktop/code/python/matplotlib")
# Out:
# /Users/baidengchao/Desktop/code/python/matplotlib

# %%
# 创建数据
x=[i for i in range(60)]
y_bj=[random.uniform(5,18) for i in range(60)]
print(y_bj)
y_js=[random.uniform(16,23) for i in range(60)]
print(y_js)
# Out:
# [11.76157055549044, 9.906994285997866, 11.256986069947967, 11.130268835564284, 15.959757019124044, 12.341882560873888, 17.641421857863307, 13.609917988391484, 7.669226888411506, 12.578558990699797, 8.901449414558225, 14.354186199053542, 5.0238519881452675, 9.66427307030104, 17.599128706723683, 5.842777707325866, 13.605726525823265, 7.3539839973104595, 12.974405608458857, 10.092258195160609, 7.598012176534818, 14.338632934249324, 17.25189477081799, 10.675717959374804, 13.71729832656549, 17.369973958209513, 9.712760984686422, 12.162247647468492, 9.080420779560185, 6.6307733653429555, 8.665311357152198, 5.570394760642205, 5.821696986772752, 12.864919232195104, 10.735157499175894, 14.216916790055807, 15.925448173199664, 11.227227767840814, 16.78407542557593, 6.438197206430706, 15.565776402890641, 12.524893581828193, 17.51877103224558, 13.824269437901053, 12.585571015466469, 7.226945138794527, 14.707627974745694, 9.663781099160985, 8.27011443682728, 10.771845351110088, 17.751049874811876,
# ...

# %%
# 创建画布
plt.figure(figsize=(30,15),dpi=80)
# 渲染图
plt.plot(x,y_bj,color="r",label="北京")
plt.plot(x,y_js,color="b",label="江苏")
# 设置 x,y 坐标轴刻度
x_ticks_label=[f"11时{i}分" for i in range(60)]
y_ticks=[i for i in range(0,30)]
plt.xticks(x[::5],x_ticks_label[::5])
plt.yticks(y_ticks[::5])
# 设置坐标轴文本信息
plt.ylabel("温度",fontsize=15)
plt.xlabel("时间",fontsize=15)

# 图标题
plt.title("北京/江苏温度统计图",fontsize=20)

# 图例
plt.legend(loc=0,fontsize=15)
# 保存图片
plt.savefig('./images/doubleTemp.jpeg')

# 展示图形
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# ...

# %% [markdown]
# ## 面向对象方式绘图 -> 1个画板多个坐标系

# %%
# 创建数据
# 创建数据
x=range(60)
y_bj=[random.uniform(5,20) for i in x]
print(y_bj)
y_js=[random.uniform(12,26) for i in x]
print(y_js)
# Out:
# [19.7570758158068, 19.071322610136946, 13.688488137900197, 16.32603650820326, 6.079762526257403, 10.331888848272177, 12.848209417868894, 11.490422592141094, 9.944934952946454, 11.47990859789996, 5.226098171175584, 18.705395421291072, 14.85645979806201, 10.511605283594658, 19.4658120655285, 12.996521195058074, 18.503593592567245, 12.444069821171823, 12.898634778535925, 12.74052523821075, 16.87822738370128, 6.6812486431529, 5.596653697112725, 16.397297673334478, 13.243499014536532, 13.19730820367238, 9.908937352472279, 15.390078886354042, 13.749300366579531, 13.425131837239025, 9.393256016757162, 6.471826815734016, 10.682577464140124, 15.559512228632103, 18.328888195282417, 14.932849135058346, 8.672370658606553, 6.420050879884404, 6.464562123740324, 13.023065116055482, 17.55456256594187, 13.18559731962627, 19.386456374633376, 14.437032146497282, 13.95182736044151, 17.052281877676936, 6.7933824887157375, 13.795573989966506, 18.729669319052423, 7.225393554682945, 19.409229374198492, 5.08
# ...

# %%
# 创建画布

fig,ax=plt.subplots(figsize=(30,15),nrows=1,ncols=2)
y_ticks = [i for i in range(0, 30)]
# 渲染图
ax[0].plot(x,y_bj,color="r",label="北京")
ax[1].plot(x,y_js,color="b",label="江苏")

# 设置纵坐标名称
ax[0].set_ylabel("温度",fontsize=20)
ax[1].set_ylabel("温度",fontsize=20)
# 设置横坐标名称
ax[0].set_xlabel("时间",fontsize=20)
ax[1].set_xlabel("时间",fontsize=20)

# 设置横坐标刻度
ax[0].set_xticks(x[::5],[f"12时{i}分" for i in x][::5])
ax[1].set_xticks(x[::5],[f"12时{i}分" for i in x][::5])

#设置纵坐标刻度
ax[0].set_yticks(y_ticks[::5])
ax[1].set_yticks(y_ticks[::5])

# 设置网格
ax[0].grid(linestyle="--",alpha=0.5,color="g")
ax[1].grid(linestyle="-.",alpha=0.5,color="g")

# 设置图例
ax[0].legend(loc=0,fontsize=15)
ax[1].legend(loc=0,fontsize=15)

# 设置图形标题
ax[0].set_title("北京中午小时温度",fontsize=25)
ax[1].set_title("江苏中午小时温度",fontsize=25)

# 保存图表
plt.savefig('./images/beijing_jiangsu_temp.jpeg')

plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# ...
