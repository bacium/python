# %%
import numpy as np
import pandas as pd
import os

# %%
print(os.getcwd())
os.chdir("E:\python\project\python\随堂\pandas")
student=pd.read_csv("./data/students.csv")
student
# Out:
# E:\python\project\python\随堂\pandas
#   name   age
# 0   张三  15.0
# 1   李四  20.0
# 2   王五   NaN
# 3   赵六  15.0

# %%
# 用0填充
s1=student.fillna(0)
print(s1)
# Out:
#   name   age
# 0   张三  15.0
# 1   李四  20.0
# 2   王五   0.0
# 3   赵六  15.0

# %%
# 平均值填充
s2=student.fillna(student["age"].mean())
s2
# Out:
#   name        age
# 0   张三  15.000000
# 1   李四  20.000000
# 2   王五  16.666667
# 3   赵六  15.000000

# %%
# 使用后面不为none的值填充
s3=student.bfill()
s3
# Out:
#   name   age
# 0   张三  15.0
# 1   李四  20.0
# 2   王五  15.0
# 3   赵六  15.0

# %%
# 使用前值填充
s4=student.ffill()
s4
# Out:
#   name   age
# 0   张三  15.0
# 1   李四  20.0
# 2   王五  20.0
# 3   赵六  15.0
