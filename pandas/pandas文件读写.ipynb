# %% [markdown]
# # pandas文件读写操作

# %%
import pandas as pd
import os
os.chdir("E:\python\project\python\pandas")

# %%
# allDs=pd.read_csv("./data/stock_day.csv")  读取所有列的数据
partDs=pd.read_csv("./data/stock_day.csv",usecols=["open","high","low","close"]) # 读取指定列的数据
partDs.head()
# Out:
#              open   high  close    low
# 2018-02-27  23.53  25.88  24.16  23.53
# 2018-02-26  22.80  23.78  23.53  22.80
# 2018-02-23  22.88  23.37  22.82  22.71
# 2018-02-22  22.25  22.76  22.28  22.02
# 2018-02-14  21.49  21.99  21.92  21.48

# %%
#写入数据
# 1写入数据,包括索引和列名
# partDs.head(10).to_csv("./data/output_csv.csv",sep=",") 
# 2写入数据不包含索引
# partDs.head(10).to_csv("./data/output2_csv.csv",sep=",",index=False,header=True) 
# 3写入纯数据,不包含索引和列名
# partDs.head(10).to_csv("./data/output3_csv.csv",sep=",",index=False,header=False) 
# 4 写入数据包含索引和列名,但是不覆盖原有数据,追加到后面
partDs.head(10).to_csv("./data/output_csv.csv",sep=",",mode="a") 
print("写入成功")
# Out:
# 写入成功
