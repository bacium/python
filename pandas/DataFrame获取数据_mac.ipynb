# %% [markdown]
# # DataFrane 获取数据

# %%
# 导包
import pandas as pd
import os

# %%
# 修改工作路径
os.chdir("/Users/baidengchao/Desktop/code/python/pandas")
crd=os.getcwd()
crd
# Out:
# '/Users/baidengchao/Desktop/code/python/pandas'

# %%
 ## 1 读取数据
ds=pd.read_csv('./data/stock_day.csv')
ds.head(10)
# Out:
#              open   high  close    low    volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48  23331.04          0.44      2.05
# 2018-02-13  21.40  21.90  21.48  21.31  30802.45          0.28      1.32
# 2018-02-12  20.70  21.40  21.19  20.63  32445.39          0.82      4.03
# 2018-02-09  21.20  21.46  20.36  20.19  54304.01         -1.50     -6.86
# 2018-02-08  21.79  22.09  21.88  21.75  27068.16          0.09      0.41
# 2018-02-07  22.69  23.11  21.80  21.29  53853.25         -0.50     -2.24
#
#                ma5    ma10    ma20     v_ma5    v_ma10    v_ma20  turnover
# 2018-02-27  22.942  22.142  22.875  53782.64  46738.65  55576.11      2.39
# ...

# %% [markdown]
# ## 1 获取数据

# %%
# 根据索引获取具体数据(例如:第一行第一列) [先列后行]
value=ds["open"]["2018-02-27"]
value1=ds["close"]["2018-02-27"]
value1
# Out:
# np.float64(24.16)

# %%
#通过loc属性来获取，只能通过：行索引+列名的方式来获取
value2=ds.loc["2018-02-27","open"]
value3=ds.loc["2018-02-27"]["close"]
print(value3)
# Out:
# 24.16

# %%
# 需求：获取从2018-02-27 - 2018-02-22的open列数据
targetList=ds.loc["2018-02-27":"2018-02-22"]
# print(targetList)
# 需求：获取从2018-02-27 - 2018-02-22的open, high, close, low列数据
table=ds.loc["2018-02-27":"2018-02-22",["open","close","high","low"]]
# 需求：获取从2018-02-27 - 2018-02-22的所有列数据
list1=ds.loc["2018-02-27":"2018-02-22"]
list2=ds.loc["2018-02-27":"2018-02-22",:]
# list2

# %%
#根据行号和列号获取数据
# 格式 先行后列,行和列的编号  数据源[行号,列号]
list4=ds.iloc[0,1]
# 根据行号和列号获取范围(区间)数据 
# 获取0到5行的所有列
list5=ds.iloc[0:5,:]
# 获取0到5行的0到6列数据
list6=ds.iloc[0:5,0:6]
# list6

# %% [markdown]
# ## 2 添加和删除列

# %%
# 添加新列
# 添加列 数据源[列名] 如果列名存在则为修改值,如果不存在则添加新列
# ds["diff_close"]=ds["close"]-ds["open"]
# 删除列
"""
    格式: 数据源drop([列名],axis=1,inplace=True) 
    参数说明: 
        1、删除一列直接写列名即可,多列用[]包裹,
        2、axis 1代表列,0代表行
        3、inplace: 布尔值,是否修改源数据
"""
# ds.drop(["ma5","ma10","ma20","v_ma5","v_ma10","v_ma20"],axis=1,inplace=True)
ds
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# ...           ...    ...    ...    ...        ...           ...       ...
# 2015-03-06  13.17  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05  12.88  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04  12.80  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03  12.52  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02  12.25  12.67  12.52  12.20   96291.73          0.32      2.62
#
#             turnover  diff_close
# 2018-02-27      2.39        0.63
# ...

# %% [markdown]
# ## 3 DataFrame和Series的排序操作

# %%
ds
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# ...           ...    ...    ...    ...        ...           ...       ...
# 2015-03-06  13.17  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05  12.88  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04  12.80  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03  12.52  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02  12.25  12.67  12.52  12.20   96291.73          0.32      2.62
#
#             turnover  diff_close
# 2018-02-27      2.39        0.63
# ...
