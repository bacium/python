# %% [markdown]
# # pandas 基本操作-根据索引获取数据

# %%
# 导包
import pandas as pd
import os

# %%
# 读取文件数据
current_dir = os.getcwd()
os.chdir("E:\python\project\python\pandas")
print(current_dir)
sd=pd.read_csv('./data/stock_day.csv')
sd.head(10)
# print(sourceData)
# Out:
# E:\python\project\python\pandas
#              open   high  close    low    volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48  23331.04          0.44      2.05
# 2018-02-13  21.40  21.90  21.48  21.31  30802.45          0.28      1.32
# 2018-02-12  20.70  21.40  21.19  20.63  32445.39          0.82      4.03
# 2018-02-09  21.20  21.46  20.36  20.19  54304.01         -1.50     -6.86
# 2018-02-08  21.79  22.09  21.88  21.75  27068.16          0.09      0.41
# 2018-02-07  22.69  23.11  21.80  21.29  53853.25         -0.50     -2.24
#
#                ma5    ma10    ma20     v_ma5    v_ma10    v_ma20  turnover
# ...

# %% [markdown]
# ## 1 获取数据

# %%
# 根据索引获取具体数据(例如:第一行第一列) [先列后行]
value1=sd["open"]["2018-02-27"]
value2=sd["high"]['2018-02-07']
value2
# Out:
# np.float64(23.11)

# %%
#通过loc属性来获取，只能通过：行索引+列名的方式来获取
# 格式 loc[行索引][列名]或者是loc[行索引,列名]
cr1=sd.loc["2018-02-27"]['close']
cr2=sd.loc["2018-02-27","low"]
cr2
# Out:
# np.float64(23.53)

# %%
# 需求：获取从2018-02-27 - 2018-02-22的open列数据
# 格式  ====> 数据源.loc[起始行索引:结束行索引]
range_row=sd.loc["2018-02-27":"2018-02-22"]
# 需求：获取从2018-02-27 - 2018-02-22的open, high, close, low列数据
# 格式 ====>数据源.loc[起始行索引:结束行索引,列名(适用于单列情况)]  或者是 数据源.loc[起始行索引:结束行索引,[列名1,列名2,列名3.....](适用于多列情况)]
range_row2=sd.loc["2018-02-27":"2018-02-22",["open","high","close","low"]]

# 需求：获取从2018-02-27 - 2018-02-22的所有列数据
# 格式====> 数据源.loc[起始行索引:结束行索引] 或者是 数据源.loc[起始行索引:结束行索引, :]  ***** ":" 指起始至结束
range_row3=sd.loc["2018-02-27":"2018-02-22"]
range_row4=sd.loc["2018-02-27":"2018-02-22",:]
#range_row4

# %% [markdown]
# ## 2 添加和删除列

# %%
# 添加列 
# 添加列 数据源[列名] 如果列名存在则为修改值,如果不存在则添加新列
#sd["diff_open"]=sd["open"]-sd["close"]
sd
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# ...           ...    ...    ...    ...        ...           ...       ...
# 2015-03-06  13.17  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05  12.88  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04  12.80  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03  12.52  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02  12.25  12.67  12.52  12.20   96291.73          0.32      2.62
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20  turnover
# ...

# %%
# 删除列
#sd.drop(["ma5","ma10","ma20","v_ma5","v_ma10","v_ma20"],axis=1,inplace=True)

# %% [markdown]
# ## 3 DataFrame和Series的排序操作

# %%
# DataFrame 排序
# 1根据索引排序
# sd.sort_index(ascending=True,inplace=True) # ascending True:升序.False 降序

# %%
# 2 根据值排序
# sd.sort_values("open",ascending=False,inplace=True)
# 多列值排序
# sd.sort_values(["open","high"],ascending=[True,False],inplace=True)
# sd

# %%
# Series 排序
# temp=sd["open"]
# temp.sort_index(ascending=True,inplace=True)
sdc=sd.copy()
sdc.open.sort_values(ascending=False)
# Out:
# 2015-06-15    34.99
# 2015-06-12    34.69
# 2015-06-10    34.10
# 2017-11-01    33.85
# 2015-06-11    33.17
#               ...
# 2015-03-05    12.88
# 2015-03-04    12.80
# 2015-03-03    12.52
# 2015-09-02    12.30
# 2015-03-02    12.25
# Name: open, Length: 643, dtype: float64
